# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_to_csv = '/content/gdrive/MyDrive/neural network/diabetes.csv'

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# Using TensorFlow's integrated Keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense , Activation

# Define the path to the uploaded dataset
path_to_csv = '/content/gdrive/MyDrive/neural network/diabetes.csv'

# Load the dataset
dataset = pd.read_csv(path_to_csv, header=None).values

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)

# Seed for reproducibility
np.random.seed(155)

# Define the neural network model
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print model summary and evaluation results
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 21.6099 - acc: 0.6615
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 14.3531 - acc: 0.6597
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 7.2794 - acc: 0.6580
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.4929 - acc: 0.5295
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0619 - acc: 0.5226
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.8639 - acc: 0.5538
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.7661 - acc: 0.5399
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.6519 - acc: 0.5573
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.5817 - acc: 0.5556
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 1.4959 - acc: 0.5781
# Epoch 11/100
# ...

# %% [markdown]
# First Part

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# Using TensorFlow's integrated Keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation

# Define the path to the uploaded dataset
path_to_csv = '/content/gdrive/MyDrive/neural network/diabetes.csv'

# Load the dataset
dataset = pd.read_csv(path_to_csv, header=None).values

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)

# Seed for reproducibility
np.random.seed(155)

# Define the neural network model
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(15, input_dim=8, activation='relu')) # additional hidden layer
my_first_nn.add(Dense(10, input_dim=8, activation='relu')) # additional hidden layer
my_first_nn.add(Dense(5, input_dim=8, activation='relu')) # additional hidden layer
my_first_nn.add(Dense(3, input_dim=8, activation='relu')) # additional hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print model summary and evaluation results
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# 18/18 [==============================] - 2s 4ms/step - loss: 1.2651 - acc: 0.3993
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7074 - acc: 0.5955
# Epoch 3/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6780 - acc: 0.6319
# Epoch 4/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6649 - acc: 0.6458
# Epoch 5/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6544 - acc: 0.6632
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6461 - acc: 0.6441
# Epoch 7/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6396 - acc: 0.6493
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6373 - acc: 0.6562
# Epoch 9/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6327 - acc: 0.6580
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6283 - acc: 0.6528
# Epoch 11/100
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# Assuming path_to_csv is the path to your dataset
path_to_csv = '/content/gdrive/MyDrive/neural network/Breas Cancer.csv'

dataset = pd.read_csv(path_to_csv)

# Convert 'M' to 0 and 'B' to 1
dataset['diagnosis'] = dataset['diagnosis'].replace({'M': 0, 'B': 1})

# Assuming the 'diagnose' column is the target and the others are features
X = dataset.drop('diagnosis', axis=1).values
Y = dataset['diagnosis'].values

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Define the neural network model
my_first_nn = Sequential()
my_first_nn.add(Dense(20, input_dim=X_train.shape[1], activation='relu')) # hidden layer
my_first_nn.add(Dense(15, activation='sigmoid')) # output layer
my_first_nn.add(Dense(10, activation='sigmoid')) # output layer
my_first_nn.add(Dense(8, activation='sigmoid')) # output layer
my_first_nn.add(Dense(6, activation='sigmoid')) # output layer
my_first_nn.add(Dense(4, activation='sigmoid')) # output layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print model summary and evaluation results
print(my_first_nn.summary())
loss , accuracy = my_first_nn.evaluate(X_test, Y_test)
print("Acuracy :" , accuracy)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 5ms/step - loss: nan - acc: 0.3803
# Epoch 2/100
# 14/14 [==============================] - 0s 6ms/step - loss: nan - acc: 0.3803
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: nan - acc: 0.3803
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: nan - acc: 0.3803
# Epoch 6/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 8/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: nan - acc: 0.3803
# Epoch 10/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 11/100
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.layers import Dense
from keras.models import Sequential

# Assuming path_to_csv is the path to your dataset
path_to_csv = '/content/gdrive/MyDrive/neural network/Breas Cancer.csv'

dataset = pd.read_csv(path_to_csv)

# Convert 'M' to 0 and 'B' to 1
dataset['diagnosis'] = dataset['diagnosis'].replace({'M': 0, 'B': 1})

# Assuming the 'diagnose' column is the target and the others are features
X = dataset.drop('diagnosis', axis=1).values
Y = dataset['diagnosis'].values

# Normalize the input features
sc = StandardScaler()
X = sc.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)


np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=32, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Evaluate the model
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))

loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1047: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1052: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1072: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# 14/14 [==============================] - 1s 3ms/step - loss: nan - acc: 0.3803
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: nan - acc: 0.3803
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: nan - acc: 0.3803
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: nan - acc: 0.3803
# Epoch 5/100
# ...

# %% [markdown]
# Second part

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 2s 5ms/step - loss: 0.2901 - accuracy: 0.9094 - val_loss: 0.2359 - val_accuracy: 0.9223
# Epoch 2/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0990 - accuracy: 0.9690 - val_loss: 0.1092 - val_accuracy: 0.9668
# Epoch 3/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0633 - accuracy: 0.9803 - val_loss: 0.0807 - val_accuracy: 0.9749
# Epoch 4/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.0693 - val_accuracy: 0.9793
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 0.0804 - val_accuracy: 0.9761
# Epoch 6/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0663 - val_accuracy: 0.9806
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# select a random image from test data
image_index = 124
img = test_images[image_index]

# plot the image
plt.imshow(img, cmap='gray')

# reshape image to 1D vector
img = img.reshape((1, 784))

# normalize pixel values
img = img / 255.0

# predict class of image
result = model.predict(img)
print("Predicted digit:", np.argmax(result))
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Predicted digit: 7

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(dimData,)))
model.add(Dense(256, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 7s 10ms/step - loss: 0.3293 - accuracy: 0.8996 - val_loss: 0.2125 - val_accuracy: 0.9352
# Epoch 2/10
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1462 - accuracy: 0.9568 - val_loss: 0.1394 - val_accuracy: 0.9588
# Epoch 3/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0971 - accuracy: 0.9711 - val_loss: 0.1003 - val_accuracy: 0.9699
# Epoch 4/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 0.9784 - val_loss: 0.1093 - val_accuracy: 0.9645
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0541 - accuracy: 0.9835 - val_loss: 0.0826 - val_accuracy: 0.9737
# Epoch 6/10
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0406 - accuracy: 0.9876 - val_loss: 0.0728 - val_accuracy: 0.9778
# Epoch 7/10
# ...

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
test_loss, test_acc = model.evaluate(test_data, test_labels_one_hot, verbose=0)
print(f'Test loss: {test_loss:.3f}, Test accuracy: {test_acc:.3f}')
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 2s 6ms/step - loss: 6.2825 - accuracy: 0.8781 - val_loss: 0.7525 - val_accuracy: 0.9182
# Epoch 2/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4244 - accuracy: 0.9475 - val_loss: 0.6068 - val_accuracy: 0.9050
# Epoch 3/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2490 - accuracy: 0.9586 - val_loss: 0.3147 - val_accuracy: 0.9533
# Epoch 4/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1966 - accuracy: 0.9663 - val_loss: 0.3545 - val_accuracy: 0.9540
# Epoch 5/10
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1711 - accuracy: 0.9734 - val_loss: 0.2579 - val_accuracy: 0.9639
# Epoch 6/10
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1530 - accuracy: 0.9759 - val_loss: 0.3198 - val_accuracy: 0.9641
# Epoch 7/10
# ...
